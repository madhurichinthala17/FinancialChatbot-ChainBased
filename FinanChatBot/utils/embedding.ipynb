# %%
from langchain_ollama import OllamaEmbeddings
import sys

sys.path.append(r"C:\Users\madhu\FinancialChatbot-ChainBased\FinanChatBot")

from utils.chunking import final_docs
from langchain_chroma import Chroma
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       2 import sys
#       3
#       4 sys.path.append(r"C:\Users\madhu\FinancialChatbot-ChainBased\FinanChatBot")
#       5
# ----> 6 from FinanChatBot.utils.chunking import final_docs
#       7 from langchain_chroma import Chroma
#
# ModuleNotFoundError: No module named 'FinanChatBot'

# %%
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
import pprint

pprint.pprint(dir(Chroma))
# Out:
# ['_Chroma__ensure_collection',
#  '_Chroma__query_collection',
#  '_LANGCHAIN_DEFAULT_COLLECTION_NAME',
#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_asimilarity_search_with_relevance_scores',
#  '_collection',
#  '_cosine_relevance_score_fn',
#  '_euclidean_relevance_score_fn',
#  '_get_retriever_tags',
#  '_max_inner_product_relevance_score_fn',
#  '_select_relevance_score_fn',
#  '_similarity_search_with_relevance_scores',
#  'aadd_documents',
#  'aadd_texts',
#  'add_documents',
#  'add_images',
#  'add_texts',
#  'adelete',
#  'afrom_documents',
#  'afrom_texts',
#  'aget_by_ids',
#  'amax_marginal_relevance_search',
#  'amax_marginal_relevance_search_by_vector',
#  'as_retriever',
#  'asearch',
#  'asimilarity_search',
#  'asimilarity_search_by_vector',
#  'asimilarity_search_with_relevance_scores',
#  'asimilarity_search_with_score',
#  'delete',
#  'delete_collection',
#  'embeddings',
#  'encode_image',
#  'fork',
#  'from_documents',
#  'from_texts',
#  'get',
#  'get_by_ids',
#  'hybrid_search',
#  'max_marginal_relevance_search',
#  'max_marginal_relevance_search_by_vector',
#  'reset_collection',
#  'search',
#  'similarity_search',
#  'similarity_search_by_image',
#  'similarity_search_by_image_with_relevance_score',
#  'similarity_search_by_vector',
#  'similarity_search_by_vector_with_relevance_scores',
#  'similarity_search_with_relevance_scores',
#  'similarity_search_with_score',
#  'similarity_search_with_vectors',
#  'update_document',
#  'update_documents']

# %%
chromastore = Chroma.from_documents(
    documents = final_docs,
    collection_name="JPMorganSEC",
    embedding=embeddings,
    persist_directory="./chroma_langchain_db",
)
